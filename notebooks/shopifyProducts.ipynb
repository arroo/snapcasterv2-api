# %%
"""
Notebook to explore reconstructing store inventory from myshopify.com/products.json

References:
https://practicaldatascience.co.uk/data-science/how-to-scrape-a-shopify-site-in-python-via-products-json
"""
import json
import pandas as pd
import requests

# %%
def to_df(products_json):
    """
    Convert products.json to a pandas DataFrame.
    Args:
        products_json (json): Products.json from the store.
    Returns:
        df: Pandas DataFrame of the products.json.
    """

    try:
        products_dict = json.loads(products_json)
        df = pd.DataFrame.from_dict(products_dict['products'])
        return df
    except Exception as e:
        print(e)

# %%
def get_json(url, page):
    """
    Get Shopify products.json from a store URL.
    Args:
        url (str): URL of the store.
        page (int): Page number of the products.json.
    Returns:
        products_json: Products.json from the store.
    """

    try:
        response = requests.get(f'{url}/products.json?limit=250&page={page}', timeout=5)
        products_json = response.text
        response.raise_for_status()
        return products_json

    except requests.exceptions.HTTPError as error_http:
        print("HTTP Error:", error_http)

    except requests.exceptions.ConnectionError as error_connection:
        print("Connection Error:", error_connection)

    except requests.exceptions.Timeout as error_timeout:
        print("Timeout Error:", error_timeout)

    except requests.exceptions.RequestException as error:
        print("Error: ", error)

# %%
url = 'https://hfxgames.com'

result_df = pd.DataFrame()

products_json_1 = get_json('https://hfxgames.com', 1)

# print pretty json
print(json.dumps(json.loads(products_json_1), indent=4, sort_keys=True))

df = to_df(products_json_1)
print(df['product_type'].value_counts())
# Out:
# {
#     "products": [
#         {
#             "body_html": "<p data-mce-fragment=\"1\"><strong data-mce-fragment=\"1\">Number of Players:</strong><span data-mce-fragment=\"1\">\u00a0</span>2+</p>\n<p data-mce-fragment=\"1\"><strong data-mce-fragment=\"1\">Playing Time:</strong><span data-mce-fragment=\"1\">\u00a0</span>20 Minutes</p>\n<p data-mce-fragment=\"1\"><strong data-mce-fragment=\"1\">Recommended Ages:</strong><span data-mce-fragment=\"1\">\u00a0</span>8+</p>\n<p data-mce-fragment=\"1\"><strong data-mce-fragment=\"1\"><br data-mce-fragment=\"1\">In This Game, Your Useless Knowledge Will Win You Useful Points</strong></p>\n<p data-mce-fragment=\"1\">Think fast, not hard in this merciless word-shouting board game. Start by drawing a category card. Your team will then shout words from that category that begin with the letter on the race track. Move along the track every time you get a word right and race against your opponents to win. This is a simple game for versatile occasions. Play it as a two-player game for a casual night-in or bring it along as a party game for big groups.</p>\n<p data-mce-fragment=\"1\">Really Loud Librarians comes with:</p>\n<ul data-mce-fragment=\"1\">\n<li data-mce-fragment=\"1\">1 Game Board</li>\n<li data-mce-fragment=\"1\">60 Category Cards</li>\n<li data-mce-fragment=\"1\">2 Librarians</li>\n<li data-mce-fragment=\"1\">20 Letter Tiles</li>\n<li data-mce-fragment=\"1\">14 Tokens</li>\n<li data-mce-fragment=\"1\">2 Score Markers</li>\n<li data-mce-fragment=\"1\">1 Chain</li>\n<li data-mce-fragment=\"1\">1 Timer</li>\n</ul>\n<p data-mce-fragment=\"1\">Plus, one instruction manual that you will probably skim.</p>",
#             "created_at": "2023-07-25T13:15:19-03:00",
#             "handle": "really-loud-librarians",
#             "id": 8053009907875,
#             "images": [
#                 {
#                     "created_at": "2023-07-25T13:16:10-03:00",
#                     "height": 715,
#                     "id": 37444535222435,
#                     "position": 1,
#                     "product_id": 8053009907875,
#                     "src": "https://cdn.shopify.com/s/files/1/0316/5585/4215/files/LoudLibrarians.png?v=1690301771",
#                     "updated_at": "2023-07-25T13:16:11-03:00",
#                     "variant_ids": [],
#                     "width": 718
#                 },
#                 {
#                     "created_at": "2023-07-25T13:16:17-03:00",
#                     "height": 860,
#                     "id": 37444535648419,
#                     "position": 2,
#                     "product_id": 8053009907875,
#                     "src": "https://cdn.shopify.com/s/files/1/0316/5585/4215/files/LoudLibrarians2.png?v=1690301778",
#                     "updated_at": "2023-07-25T13:16:18-03:00",
#                     "variant_ids": [],
#                     "width": 1324
#                 }
#             ],
#             "options": [
#                 {
#                     "name": "Title",
#                     "position": 1,
#                     "values": [
#                         "Default Title"
#                     ]
#                 }
#             ],
#             "product_type": "Board Game",
#             "published_at": "2023-07-25T13:18:57-03:00",
#             "tags": [
#                 "2+ Players",
#                 "20 Min.",
#                 "Board Games"
#             ],
#             "title": "Really Loud Librarians",
#             "updated_at": "2023-07-25T13:21:16-03:00",
#             "variants": [
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-25T13:15:19-03:00",
#                     "featured_image": null,
#                     "grams": 0,
#                     "id": 43481525518499,
#                     "option1": "Default Title",
#                     "option2": null,
#                     "option3": null,
#                     "position": 1,
#                     "price": "24.99",
#                     "product_id": 8053009907875,
#                     "requires_shipping": true,
#                     "sku": "",
#                     "taxable": true,
#                     "title": "Default Title",
#                     "updated_at": "2023-07-25T13:21:16-03:00"
#                 }
#             ],
#             "vendor": "Universal Distribution"
#         },
#         {
#             "body_html": "<p><strong>Number of Players:\u00a0</strong>1-4<br><strong>Playing Time:</strong><span>\u00a0</span>60-90 Minutes<br><strong>Recommended Ages:</strong><span>\u00a0</span>8+</p>\n<p>The Isle of Cats is a competitive, medium-weight, card-drafting, polyomino cat-placement board game for 1-4 players (6 with expansions).</p>\n<p>You are citizens of Squalls End on a rescue mission to The Isle of Cats and must rescue as many cats as possible before the evil Lord Vesh arrives. Each cat is represented by a unique tile and belongs to a family, you must find a way to make them all fit on your boat while keeping families together.</p>\n<p>You will also need to manage resources as you:</p>\n<ul>\n<li>Explore the island (by drafting cards)</li>\n<li>Rescue cats</li>\n<li>Find treasures</li>\n<li>Befriend Oshax</li>\n<li>Study ancient lessons</li>\n</ul>\n<p>Each lesson you collect will give you another personal way of scoring points, and there are 38 unique lessons available.</p>\n<p>Complete lessons, fill your boat, and keep cat families together to score points, the winner will be the player with the most points after five rounds.</p>",
#             "created_at": "2023-07-25T13:07:24-03:00",
#             "handle": "the-isle-of-cats",
#             "id": 8053005287587,
#             "images": [
#                 {
#                     "created_at": "2023-07-25T13:12:38-03:00",
#                     "height": 1200,
#                     "id": 37444499603619,
#                     "position": 1,
#                     "product_id": 8053005287587,
#                     "src": "https://cdn.shopify.com/s/files/1/0316/5585/4215/files/Isle-of-Cats.png?v=1690301559",
#                     "updated_at": "2023-07-25T13:12:39-03:00",
#                     "variant_ids": [],
#                     "width": 945
#                 },
#                 {
#                     "created_at": "2023-07-25T13:12:38-03:00",
#                     "height": 1197,
#                     "id": 37444499669155,
#                     "position": 2,
#                     "product_id": 8053005287587,
#                     "src": "https://cdn.shopify.com/s/files/1/0316/5585/4215/files/Isle-of-Cats-2.png?v=1690301560",
#                     "updated_at": "2023-07-25T13:12:40-03:00",
#                     "variant_ids": [],
#                     "width": 1800
#                 }
#             ],
#             "options": [
#                 {
#                     "name": "Title",
#                     "position": 1,
#                     "values": [
#                         "Default Title"
#                     ]
#                 }
#             ],
#             "product_type": "Board Game",
#             "published_at": "2023-07-25T13:14:23-03:00",
#             "tags": [
#                 "1-4 Players",
#                 "60 - 90 min.",
#                 "Board Games"
#             ],
#             "title": "The Isle of Cats",
#             "updated_at": "2023-07-25T13:21:16-03:00",
#             "variants": [
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-25T13:07:24-03:00",
#                     "featured_image": null,
#                     "grams": 0,
#                     "id": 43481515983011,
#                     "option1": "Default Title",
#                     "option2": null,
#                     "option3": null,
#                     "position": 1,
#                     "price": "55.99",
#                     "product_id": 8053005287587,
#                     "requires_shipping": true,
#                     "sku": "",
#                     "taxable": true,
#                     "title": "Default Title",
#                     "updated_at": "2023-07-25T13:21:16-03:00"
#                 }
#             ],
#             "vendor": "Universal Distribution"
#         },
#         {
#             "body_html": "<p data-mce-fragment=\"1\"><strong data-mce-fragment=\"1\">Number of Players:</strong><span data-mce-fragment=\"1\">\u00a0</span>2-5<br data-mce-fragment=\"1\"><strong data-mce-fragment=\"1\">Playing Time:</strong><span data-mce-fragment=\"1\">\u00a0</span>15 Minutes<br data-mce-fragment=\"1\"><strong data-mce-fragment=\"1\">Recommended Ages:</strong><span data-mce-fragment=\"1\">\u00a0</span>7+\u00a0</p>\n<p data-mce-fragment=\"1\">This is the most high-stakes version of Exploding Kittens yet!<br data-mce-fragment=\"1\"><br data-mce-fragment=\"1\">New rules. New Kittens. New mayhem. This version of Exploding Kittens features new cards and gameplay based on the Netflix animated series Exploding Kittens, premiering near the end of 2023. It's still the highly-strategic kitty powered version of Russian Roulette you know and love with new Armageddon Cards which set up an epic battle of Good vs. Evil. Outsmart your opponent. Try not to explode. The last player left alive wins.</p>",
#             "created_at": "2023-07-25T13:02:38-03:00",
#             "handle": "exploding-kittens-good-vs-evil",
#             "id": 8053001781411,
#             "images": [
#                 {
#                     "created_at": "2023-07-25T13:03:45-03:00",
#                     "height": 701,
#                     "id": 37444410278051,
#                     "position": 1,
#                     "product_id": 8053001781411,
#                     "src": "https://cdn.shopify.com/s/files/1/0316/5585/4215/files/ExplodingKittenGvE.png?v=1690301026",
#                     "updated_at": "2023-07-25T13:03:46-03:00",
#                     "variant_ids": [],
#                     "width": 1000
#                 }
#             ],
#             "options": [
#                 {
#                     "name": "Title",
#                     "position": 1,
#                     "values": [
#                         "Default Title"
#                     ]
#                 }
#             ],
#             "product_type": "Board Game",
#             "published_at": "2023-07-25T13:06:52-03:00",
#             "tags": [
#                 "15 min.",
#                 "2 - 5 Players",
#                 "Board Games",
#                 "Party Games"
#             ],
#             "title": "Exploding Kittens Good Vs Evil",
#             "updated_at": "2023-07-25T13:21:16-03:00",
#             "variants": [
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-25T13:02:38-03:00",
#                     "featured_image": null,
#                     "grams": 0,
#                     "id": 43481505759395,
#                     "option1": "Default Title",
#                     "option2": null,
#                     "option3": null,
#                     "position": 1,
#                     "price": "29.99",
#                     "product_id": 8053001781411,
#                     "requires_shipping": true,
#                     "sku": "",
#                     "taxable": true,
#                     "title": "Default Title",
#                     "updated_at": "2023-07-25T13:21:16-03:00"
#                 }
#             ],
#             "vendor": "Universal Distribution"
#         },
#         {
#             "body_html": "<table class=\"singles-description-table\">\n<tbody>\n      <tr>\n          <td>Set:</td>\n          <td>The List</td>\n      </tr>\n      <tr>\n          <td>Type:</td>\n          <td>Artifact</td>\n      </tr>\n      <tr>\n          <td>Rarity:</td>\n          <td>Mythic</td>\n      </tr>\n      <tr>\n          <td>Cost:</td>\n          <td>{5}</td>\n      </tr>\n</tbody>\n</table>\n<div class=\"single-description-div\">\n        <div class=\"oracle-text\">\n            Ring of Three Wishes enters the battlefield with three wish counters on it.<br>5,T, Remove a wish counter from Ring of Three Wishes: Search your library for a card and put that card into your hand. Then shuffle your library.\n        </div>\n<table class=\"singles-reverse-description-table\">\n<tbody>\n</tbody>\n</table>\n<div class=\"single-description-div\">\n</div>\n<div class=\"catalogMetaData\" style=\"visibility: hidden;\" data-cardtype=\"mtg\" data-cardid=\"19948\" data-tcgid=\"498642\" data-lastupdated=\"2023-07-25T15:09:33.781Z\">\n</div>\n</div>",
#             "created_at": "2023-06-05T12:43:49-03:00",
#             "handle": "ring-of-three-wishes-the-list",
#             "id": 8033487782051,
#             "images": [
#                 {
#                     "created_at": "2023-07-25T12:10:11-03:00",
#                     "height": 700,
#                     "id": 37444084957347,
#                     "position": 1,
#                     "product_id": 8033487782051,
#                     "src": "https://cdn.shopify.com/s/files/1/0316/5585/4215/products/mtg_placeholder_609b0693-9957-4308-8c60-54f55bd0e6df.png?v=1690297811",
#                     "updated_at": "2023-07-25T12:10:11-03:00",
#                     "variant_ids": [],
#                     "width": 500
#                 }
#             ],
#             "options": [
#                 {
#                     "name": "Title",
#                     "position": 1,
#                     "values": [
#                         "Near Mint",
#                         "Lightly Played",
#                         "Moderately Played",
#                         "Heavily Played",
#                         "Damaged"
#                     ]
#                 }
#             ],
#             "product_type": "MTG Single",
#             "published_at": "2023-07-25T12:09:47-03:00",
#             "tags": [
#                 "Artifact",
#                 "Colorless",
#                 "Commander",
#                 "Duel",
#                 "Legacy",
#                 "Modern",
#                 "Mythic",
#                 "Normal",
#                 "Oathbreaker",
#                 "Penny",
#                 "Pioneer",
#                 "The List",
#                 "Vintage"
#             ],
#             "title": "Ring of Three Wishes [The List]",
#             "updated_at": "2023-07-25T12:10:11-03:00",
#             "variants": [
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:43:49-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425103216803,
#                     "option1": "Near Mint",
#                     "option2": null,
#                     "option3": null,
#                     "position": 1,
#                     "price": "3.50",
#                     "product_id": 8033487782051,
#                     "requires_shipping": true,
#                     "sku": "PLIST-216-RING-EN-NF-1",
#                     "taxable": true,
#                     "title": "Near Mint",
#                     "updated_at": "2023-07-25T12:09:49-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:43:49-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425103249571,
#                     "option1": "Lightly Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 2,
#                     "price": "3.00",
#                     "product_id": 8033487782051,
#                     "requires_shipping": true,
#                     "sku": "PLIST-216-RING-EN-NF-2",
#                     "taxable": true,
#                     "title": "Lightly Played",
#                     "updated_at": "2023-07-25T12:09:49-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:43:49-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425103282339,
#                     "option1": "Moderately Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 3,
#                     "price": "2.50",
#                     "product_id": 8033487782051,
#                     "requires_shipping": true,
#                     "sku": "PLIST-216-RING-EN-NF-3",
#                     "taxable": true,
#                     "title": "Moderately Played",
#                     "updated_at": "2023-07-25T12:09:49-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:43:49-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425103315107,
#                     "option1": "Heavily Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 4,
#                     "price": "1.75",
#                     "product_id": 8033487782051,
#                     "requires_shipping": true,
#                     "sku": "PLIST-216-RING-EN-NF-4",
#                     "taxable": true,
#                     "title": "Heavily Played",
#                     "updated_at": "2023-07-25T12:09:49-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:43:49-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425103347875,
#                     "option1": "Damaged",
#                     "option2": null,
#                     "option3": null,
#                     "position": 5,
#                     "price": "1.50",
#                     "product_id": 8033487782051,
#                     "requires_shipping": true,
#                     "sku": "PLIST-216-RING-EN-NF-5",
#                     "taxable": true,
#                     "title": "Damaged",
#                     "updated_at": "2023-07-25T12:09:49-03:00"
#                 }
#             ],
#             "vendor": "Magic: The Gathering"
#         },
#         {
#             "body_html": "<table class=\"singles-description-table\">\n<tbody>\n      <tr>\n          <td>Set:</td>\n          <td>The List</td>\n      </tr>\n      <tr>\n          <td>Type:</td>\n          <td>Legendary Creature \u2014 Human Wizard</td>\n      </tr>\n      <tr>\n          <td>Rarity:</td>\n          <td>Rare</td>\n      </tr>\n      <tr>\n          <td>Cost:</td>\n          <td>{2}{U}</td>\n      </tr>\n</tbody>\n</table>\n<div class=\"single-description-div\">\n        <div class=\"oracle-text\">\n            Whenever you or a permanent you control is the target of a spell or ability controlled by one of your opponents, you may draw a card, and if Rayne, Academy Chancellor is enchanted, you may draw another card.\n        </div>\n<table class=\"singles-reverse-description-table\">\n<tbody>\n</tbody>\n</table>\n<div class=\"single-description-div\">\n</div>\n<div class=\"catalogMetaData\" style=\"visibility: hidden;\" data-cardtype=\"mtg\" data-cardid=\"19255\" data-tcgid=\"498640\" data-lastupdated=\"2023-07-25T15:09:25.448Z\">\n</div>\n</div>",
#             "created_at": "2023-06-05T12:43:35-03:00",
#             "handle": "rayne-academy-chancellor-the-list",
#             "id": 8033487257763,
#             "images": [
#                 {
#                     "created_at": "2023-07-25T12:10:44-03:00",
#                     "height": 700,
#                     "id": 37444089184419,
#                     "position": 1,
#                     "product_id": 8033487257763,
#                     "src": "https://cdn.shopify.com/s/files/1/0316/5585/4215/products/mtg_placeholder_d197282f-9251-42cf-aec7-204f6534931e.png?v=1690297844",
#                     "updated_at": "2023-07-25T12:10:44-03:00",
#                     "variant_ids": [],
#                     "width": 500
#                 }
#             ],
#             "options": [
#                 {
#                     "name": "Title",
#                     "position": 1,
#                     "values": [
#                         "Near Mint",
#                         "Lightly Played",
#                         "Moderately Played",
#                         "Heavily Played",
#                         "Damaged"
#                     ]
#                 }
#             ],
#             "product_type": "MTG Single",
#             "published_at": "2023-07-25T12:09:42-03:00",
#             "tags": [
#                 "Blue",
#                 "Commander",
#                 "Duel",
#                 "Human Wizard",
#                 "Legacy",
#                 "Legendary Creature",
#                 "Normal",
#                 "Oathbreaker",
#                 "Predh",
#                 "Premodern",
#                 "Rare",
#                 "The List",
#                 "Vintage"
#             ],
#             "title": "Rayne, Academy Chancellor [The List]",
#             "updated_at": "2023-07-25T12:10:45-03:00",
#             "variants": [
#                 {
#                     "available": true,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:43:35-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425100791971,
#                     "option1": "Near Mint",
#                     "option2": null,
#                     "option3": null,
#                     "position": 1,
#                     "price": "0.99",
#                     "product_id": 8033487257763,
#                     "requires_shipping": true,
#                     "sku": "PLIST-43-RAYNE-EN-NF-1",
#                     "taxable": true,
#                     "title": "Near Mint",
#                     "updated_at": "2023-07-25T12:09:44-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:43:35-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425100824739,
#                     "option1": "Lightly Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 2,
#                     "price": "0.89",
#                     "product_id": 8033487257763,
#                     "requires_shipping": true,
#                     "sku": "PLIST-43-RAYNE-EN-NF-2",
#                     "taxable": true,
#                     "title": "Lightly Played",
#                     "updated_at": "2023-07-25T12:09:44-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:43:35-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425100857507,
#                     "option1": "Moderately Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 3,
#                     "price": "0.69",
#                     "product_id": 8033487257763,
#                     "requires_shipping": true,
#                     "sku": "PLIST-43-RAYNE-EN-NF-3",
#                     "taxable": true,
#                     "title": "Moderately Played",
#                     "updated_at": "2023-07-25T12:09:44-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:43:35-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425100890275,
#                     "option1": "Heavily Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 4,
#                     "price": "0.49",
#                     "product_id": 8033487257763,
#                     "requires_shipping": true,
#                     "sku": "PLIST-43-RAYNE-EN-NF-4",
#                     "taxable": true,
#                     "title": "Heavily Played",
#                     "updated_at": "2023-07-25T12:09:44-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:43:35-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425100923043,
#                     "option1": "Damaged",
#                     "option2": null,
#                     "option3": null,
#                     "position": 5,
#                     "price": "0.40",
#                     "product_id": 8033487257763,
#                     "requires_shipping": true,
#                     "sku": "PLIST-43-RAYNE-EN-NF-5",
#                     "taxable": true,
#                     "title": "Damaged",
#                     "updated_at": "2023-07-25T12:09:44-03:00"
#                 }
#             ],
#             "vendor": "Magic: The Gathering"
#         },
#         {
#             "body_html": "<table class=\"singles-description-table\">\n<tbody>\n      <tr>\n          <td>Set:</td>\n          <td>The List</td>\n      </tr>\n      <tr>\n          <td>Type:</td>\n          <td>Creature \u2014 Human Warrior Ranger</td>\n      </tr>\n      <tr>\n          <td>Rarity:</td>\n          <td>Uncommon</td>\n      </tr>\n      <tr>\n          <td>Cost:</td>\n          <td>{3}{G}</td>\n      </tr>\n</tbody>\n</table>\n<div class=\"single-description-div\">\n        <div class=\"oracle-text\">\n            Landfall \u2014 Whenever a land enters the battlefield under your control, you may pay 3G. If you do, put two +1/+1 counters on Murasa Ranger.\n        </div>\n        <div class=\"flavor-text\">\n            \u201cIf you're not prepared to fight, you'd best be prepared to die.\u201d\n        </div>\n<table class=\"singles-reverse-description-table\">\n<tbody>\n</tbody>\n</table>\n<div class=\"single-description-div\">\n</div>\n<div class=\"catalogMetaData\" style=\"visibility: hidden;\" data-cardtype=\"mtg\" data-cardid=\"16534\" data-tcgid=\"498631\" data-lastupdated=\"2023-07-25T15:09:07.103Z\">\n</div>\n</div>",
#             "created_at": "2023-06-05T12:42:30-03:00",
#             "handle": "murasa-ranger-the-list",
#             "id": 8033484964003,
#             "images": [
#                 {
#                     "created_at": "2023-07-25T12:10:17-03:00",
#                     "height": 700,
#                     "id": 37444085711011,
#                     "position": 1,
#                     "product_id": 8033484964003,
#                     "src": "https://cdn.shopify.com/s/files/1/0316/5585/4215/products/mtg_placeholder_6c9615c4-9095-42be-acc6-4eff647d523f.png?v=1690297817",
#                     "updated_at": "2023-07-25T12:10:17-03:00",
#                     "variant_ids": [],
#                     "width": 500
#                 }
#             ],
#             "options": [
#                 {
#                     "name": "Title",
#                     "position": 1,
#                     "values": [
#                         "Near Mint",
#                         "Lightly Played",
#                         "Moderately Played",
#                         "Heavily Played",
#                         "Damaged"
#                     ]
#                 }
#             ],
#             "product_type": "MTG Single",
#             "published_at": "2023-07-25T12:09:22-03:00",
#             "tags": [
#                 "Commander",
#                 "Creature",
#                 "Duel",
#                 "Green",
#                 "Human Warrior Ranger",
#                 "Legacy",
#                 "Modern",
#                 "Normal",
#                 "Oathbreaker",
#                 "Paupercommander",
#                 "Penny",
#                 "Pioneer",
#                 "The List",
#                 "Uncommon",
#                 "Vintage"
#             ],
#             "title": "Murasa Ranger [The List]",
#             "updated_at": "2023-07-25T12:10:17-03:00",
#             "variants": [
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:42:30-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425090142371,
#                     "option1": "Near Mint",
#                     "option2": null,
#                     "option3": null,
#                     "position": 1,
#                     "price": "0.49",
#                     "product_id": 8033484964003,
#                     "requires_shipping": true,
#                     "sku": "PLIST-178-MURASA-EN-NF-1",
#                     "taxable": true,
#                     "title": "Near Mint",
#                     "updated_at": "2023-07-25T12:09:23-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:42:30-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425090175139,
#                     "option1": "Lightly Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 2,
#                     "price": "0.44",
#                     "product_id": 8033484964003,
#                     "requires_shipping": true,
#                     "sku": "PLIST-178-MURASA-EN-NF-2",
#                     "taxable": true,
#                     "title": "Lightly Played",
#                     "updated_at": "2023-07-25T12:09:23-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:42:30-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425090207907,
#                     "option1": "Moderately Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 3,
#                     "price": "0.34",
#                     "product_id": 8033484964003,
#                     "requires_shipping": true,
#                     "sku": "PLIST-178-MURASA-EN-NF-3",
#                     "taxable": true,
#                     "title": "Moderately Played",
#                     "updated_at": "2023-07-25T12:09:23-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:42:30-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425090240675,
#                     "option1": "Heavily Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 4,
#                     "price": "0.24",
#                     "product_id": 8033484964003,
#                     "requires_shipping": true,
#                     "sku": "PLIST-178-MURASA-EN-NF-4",
#                     "taxable": true,
#                     "title": "Heavily Played",
#                     "updated_at": "2023-07-25T12:09:23-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:42:30-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425090273443,
#                     "option1": "Damaged",
#                     "option2": null,
#                     "option3": null,
#                     "position": 5,
#                     "price": "0.20",
#                     "product_id": 8033484964003,
#                     "requires_shipping": true,
#                     "sku": "PLIST-178-MURASA-EN-NF-5",
#                     "taxable": true,
#                     "title": "Damaged",
#                     "updated_at": "2023-07-25T12:09:23-03:00"
#                 }
#             ],
#             "vendor": "Magic: The Gathering"
#         },
#         {
#             "body_html": "<table class=\"singles-description-table\">\n<tbody>\n      <tr>\n          <td>Set:</td>\n          <td>The List</td>\n      </tr>\n      <tr>\n          <td>Rarity:</td>\n          <td>Rare</td>\n      </tr>\n</tbody>\n</table>\n<div class=\"single-description-div\">\n        <div class=\"oracle-text\">\n            First strike (This creature deals combat damage before creatures without first strike.)<br><br>Other Knight creatures you control get +1/+1 and are indestructible. (Lethal damage and effects that say \"destroy\" don't destroy them.)\n        </div>\n<table class=\"singles-reverse-description-table\">\n<tbody>\n</tbody>\n</table>\n<div class=\"single-description-div\">\n</div>\n<div class=\"catalogMetaData\" style=\"visibility: hidden;\" data-cardtype=\"mtg\" data-cardid=\"15271\" data-tcgid=\"498627\" data-lastupdated=\"2023-07-25T15:08:46.239Z\">\n</div>\n</div>",
#             "created_at": "2023-06-05T12:41:35-03:00",
#             "handle": "knight-exemplar-the-list",
#             "id": 8033483980963,
#             "images": [
#                 {
#                     "created_at": "2023-07-25T12:09:00-03:00",
#                     "height": 1040,
#                     "id": 37444076699811,
#                     "position": 1,
#                     "product_id": 8033483980963,
#                     "src": "https://cdn.shopify.com/s/files/1/0316/5585/4215/products/498627.jpg?v=1690297740",
#                     "updated_at": "2023-07-25T12:09:00-03:00",
#                     "variant_ids": [],
#                     "width": 745
#                 }
#             ],
#             "options": [
#                 {
#                     "name": "Title",
#                     "position": 1,
#                     "values": [
#                         "Near Mint",
#                         "Lightly Played",
#                         "Moderately Played",
#                         "Heavily Played",
#                         "Damaged"
#                     ]
#                 }
#             ],
#             "product_type": "MTG Single",
#             "published_at": "2023-07-25T12:08:59-03:00",
#             "tags": [
#                 "Commander",
#                 "Duel",
#                 "Legacy",
#                 "Modern",
#                 "Normal",
#                 "Oathbreaker",
#                 "Penny",
#                 "Predh",
#                 "Rare",
#                 "The List",
#                 "Vintage"
#             ],
#             "title": "Knight Exemplar (20) [The List]",
#             "updated_at": "2023-07-25T12:09:01-03:00",
#             "variants": [
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:41:35-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425085423779,
#                     "option1": "Near Mint",
#                     "option2": null,
#                     "option3": null,
#                     "position": 1,
#                     "price": "2.25",
#                     "product_id": 8033483980963,
#                     "requires_shipping": true,
#                     "sku": "PLIST-20-EN-NF-1",
#                     "taxable": true,
#                     "title": "Near Mint",
#                     "updated_at": "2023-07-25T12:09:00-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:41:35-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425085456547,
#                     "option1": "Lightly Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 2,
#                     "price": "2.00",
#                     "product_id": 8033483980963,
#                     "requires_shipping": true,
#                     "sku": "PLIST-20-EN-NF-2",
#                     "taxable": true,
#                     "title": "Lightly Played",
#                     "updated_at": "2023-07-25T12:09:00-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:41:35-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425085489315,
#                     "option1": "Moderately Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 3,
#                     "price": "1.50",
#                     "product_id": 8033483980963,
#                     "requires_shipping": true,
#                     "sku": "PLIST-20-EN-NF-3",
#                     "taxable": true,
#                     "title": "Moderately Played",
#                     "updated_at": "2023-07-25T12:09:00-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:41:35-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425085522083,
#                     "option1": "Heavily Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 4,
#                     "price": "1.25",
#                     "product_id": 8033483980963,
#                     "requires_shipping": true,
#                     "sku": "PLIST-20-EN-NF-4",
#                     "taxable": true,
#                     "title": "Heavily Played",
#                     "updated_at": "2023-07-25T12:09:00-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:41:35-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425085554851,
#                     "option1": "Damaged",
#                     "option2": null,
#                     "option3": null,
#                     "position": 5,
#                     "price": "1.00",
#                     "product_id": 8033483980963,
#                     "requires_shipping": true,
#                     "sku": "PLIST-20-EN-NF-5",
#                     "taxable": true,
#                     "title": "Damaged",
#                     "updated_at": "2023-07-25T12:09:00-03:00"
#                 }
#             ],
#             "vendor": "Magic: The Gathering"
#         },
#         {
#             "body_html": "<table class=\"singles-description-table\">\n<tbody>\n      <tr>\n          <td>Set:</td>\n          <td>The List</td>\n      </tr>\n      <tr>\n          <td>Type:</td>\n          <td>Enchantment</td>\n      </tr>\n      <tr>\n          <td>Rarity:</td>\n          <td>Uncommon</td>\n      </tr>\n      <tr>\n          <td>Cost:</td>\n          <td>{G}</td>\n      </tr>\n</tbody>\n</table>\n<div class=\"single-description-div\">\n        <div class=\"oracle-text\">\n            Sacrifice a forest: Target attacking creature gets -3/-0 until end of turn.\n        </div>\n        <div class=\"flavor-text\">\n            \u201cVolrath is not the only one who can shape this world to serve him.\u201d \n\u2014Eladamri, Lord of Leaves\n        </div>\n<table class=\"singles-reverse-description-table\">\n<tbody>\n</tbody>\n</table>\n<div class=\"single-description-div\">\n</div>\n<div class=\"catalogMetaData\" style=\"visibility: hidden;\" data-cardtype=\"mtg\" data-cardid=\"8454\" data-tcgid=\"498596\" data-lastupdated=\"2023-07-25T15:08:38.827Z\">\n</div>\n</div>",
#             "created_at": "2023-06-05T12:37:01-03:00",
#             "handle": "elven-palisade-the-list",
#             "id": 8033478475939,
#             "images": [
#                 {
#                     "created_at": "2023-07-25T12:08:49-03:00",
#                     "height": 700,
#                     "id": 37444075978915,
#                     "position": 1,
#                     "product_id": 8033478475939,
#                     "src": "https://cdn.shopify.com/s/files/1/0316/5585/4215/products/mtg_placeholder_c461b2d9-5a77-44a0-8a3a-88be8a9eccd7.png?v=1690297729",
#                     "updated_at": "2023-07-25T12:08:49-03:00",
#                     "variant_ids": [],
#                     "width": 500
#                 }
#             ],
#             "options": [
#                 {
#                     "name": "Title",
#                     "position": 1,
#                     "values": [
#                         "Near Mint",
#                         "Lightly Played",
#                         "Moderately Played",
#                         "Heavily Played",
#                         "Damaged"
#                     ]
#                 }
#             ],
#             "product_type": "MTG Single",
#             "published_at": "2023-07-25T12:08:48-03:00",
#             "tags": [
#                 "Commander",
#                 "Duel",
#                 "Enchantment",
#                 "Green",
#                 "Legacy",
#                 "Normal",
#                 "Oathbreaker",
#                 "Penny",
#                 "Predh",
#                 "Premodern",
#                 "The List",
#                 "Uncommon",
#                 "Vintage"
#             ],
#             "title": "Elven Palisade [The List]",
#             "updated_at": "2023-07-25T12:08:51-03:00",
#             "variants": [
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:37:01-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425061077155,
#                     "option1": "Near Mint",
#                     "option2": null,
#                     "option3": null,
#                     "position": 1,
#                     "price": "0.75",
#                     "product_id": 8033478475939,
#                     "requires_shipping": true,
#                     "sku": "PLIST-109-ELVEN-EN-NF-1",
#                     "taxable": true,
#                     "title": "Near Mint",
#                     "updated_at": "2023-07-25T12:08:49-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:37:01-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425061109923,
#                     "option1": "Lightly Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 2,
#                     "price": "0.75",
#                     "product_id": 8033478475939,
#                     "requires_shipping": true,
#                     "sku": "PLIST-109-ELVEN-EN-NF-2",
#                     "taxable": true,
#                     "title": "Lightly Played",
#                     "updated_at": "2023-07-25T12:08:49-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:37:01-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425061142691,
#                     "option1": "Moderately Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 3,
#                     "price": "0.50",
#                     "product_id": 8033478475939,
#                     "requires_shipping": true,
#                     "sku": "PLIST-109-ELVEN-EN-NF-3",
#                     "taxable": true,
#                     "title": "Moderately Played",
#                     "updated_at": "2023-07-25T12:08:49-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:37:01-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425061175459,
#                     "option1": "Heavily Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 4,
#                     "price": "0.50",
#                     "product_id": 8033478475939,
#                     "requires_shipping": true,
#                     "sku": "PLIST-109-ELVEN-EN-NF-4",
#                     "taxable": true,
#                     "title": "Heavily Played",
#                     "updated_at": "2023-07-25T12:08:49-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-06-05T12:37:01-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43425061208227,
#                     "option1": "Damaged",
#                     "option2": null,
#                     "option3": null,
#                     "position": 5,
#                     "price": "0.50",
#                     "product_id": 8033478475939,
#                     "requires_shipping": true,
#                     "sku": "PLIST-109-ELVEN-EN-NF-5",
#                     "taxable": true,
#                     "title": "Damaged",
#                     "updated_at": "2023-07-25T12:08:49-03:00"
#                 }
#             ],
#             "vendor": "Magic: The Gathering"
#         },
#         {
#             "body_html": "<table class=\"singles-description-table\">\n<tbody>\n      <tr>\n          <td>Set:</td>\n          <td>The List</td>\n      </tr>\n      <tr>\n          <td>Type:</td>\n          <td>Enchantment</td>\n      </tr>\n      <tr>\n          <td>Rarity:</td>\n          <td>Rare</td>\n      </tr>\n      <tr>\n          <td>Cost:</td>\n          <td>{1}{W}</td>\n      </tr>\n</tbody>\n</table>\n<div class=\"single-description-div\">\n        <div class=\"oracle-text\">\n            Each creature has protection from its colors.\n        </div>\n        <div class=\"flavor-text\">\n            \u201cThe world has enough strife as it is. Where would we be if we turned against each other?\u201d \n\u2014Pianna, nomad captain\n        </div>\n<table class=\"singles-reverse-description-table\">\n<tbody>\n</tbody>\n</table>\n<div class=\"single-description-div\">\n</div>\n<div class=\"catalogMetaData\" style=\"visibility: hidden;\" data-cardtype=\"mtg\" data-cardid=\"8428\" data-tcgid=\"498594\" data-lastupdated=\"2023-07-25T15:08:22.235Z\">\n</div>\n</div>",
#             "created_at": "2023-06-05T12:36:48-03:00",
#             "handle": "earnest-fellowship-the-list",
#             "id": 8033478213795,
#             "images": [
#                 {
#                     "created_at": "2023-07-25T12:08:35-03:00",
#                     "height": 700,
#                     "id": 37444074995875,
#                     "position": 1,
#                     "product_id": 8033478213795,
#                     "src": "https://cdn.shopify.com/s/files/1/0316/5585/4215/products/mtg_placeholder_9f490b1f-c791-4be7-90cf-5113022f42fb.png?v=1690297715",
#                     "updated_at": "2023-07-25T12:08:35-03:00",
#                     "variant_ids": [],
#                     "width": 500
#                 }
#             ],
#             "options": [
#                 {
#                     "name": "Title",
#                     "position": 1,
#                     "values": [
#                         "Near Mint",
#                         "Lightly Played",
#                         "Moderately Played",
#                         "Heavily Played",
#                         "Damaged"
#                     ]
#                 }
#             ],
#             "product_type": "MTG Single",
#             "published_at": "2023-07-25T12:08:33-03:00",
#             "tags": [
#                 "Commander",
#                 "Duel",
#                 "Enchantment",
# ...
#                     "updated_at": "2023-07-24T18:30:50-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-24T18:30:50-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43480150016163,
#                     "option1": "Damaged",
#                     "option2": null,
#                     "option3": null,
#                     "position": 5,
#                     "price": "0.75",
#                     "product_id": 8052474413219,
#                     "requires_shipping": true,
#                     "sku": "CMM-312-EN-NF-5",
#                     "taxable": true,
#                     "title": "Damaged",
#                     "updated_at": "2023-07-24T18:30:50-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-24T18:30:50-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43480150048931,
#                     "option1": "Near Mint Foil",
#                     "option2": null,
#                     "option3": null,
#                     "position": 6,
#                     "price": "6.75",
#                     "product_id": 8052474413219,
#                     "requires_shipping": true,
#                     "sku": "CMM-312-EN-FO-1",
#                     "taxable": true,
#                     "title": "Near Mint Foil",
#                     "updated_at": "2023-07-24T18:30:50-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-24T18:30:50-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43480150081699,
#                     "option1": "Lightly Played Foil",
#                     "option2": null,
#                     "option3": null,
#                     "position": 7,
#                     "price": "6.00",
#                     "product_id": 8052474413219,
#                     "requires_shipping": true,
#                     "sku": "CMM-312-EN-FO-2",
#                     "taxable": true,
#                     "title": "Lightly Played Foil",
#                     "updated_at": "2023-07-24T18:30:50-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-24T18:30:50-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43480150114467,
#                     "option1": "Moderately Played Foil",
#                     "option2": null,
#                     "option3": null,
#                     "position": 8,
#                     "price": "4.75",
#                     "product_id": 8052474413219,
#                     "requires_shipping": true,
#                     "sku": "CMM-312-EN-FO-3",
#                     "taxable": true,
#                     "title": "Moderately Played Foil",
#                     "updated_at": "2023-07-24T18:30:50-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-24T18:30:50-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43480150147235,
#                     "option1": "Heavily Played Foil",
#                     "option2": null,
#                     "option3": null,
#                     "position": 9,
#                     "price": "3.50",
#                     "product_id": 8052474413219,
#                     "requires_shipping": true,
#                     "sku": "CMM-312-EN-FO-4",
#                     "taxable": true,
#                     "title": "Heavily Played Foil",
#                     "updated_at": "2023-07-24T18:30:50-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-24T18:30:50-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43480150180003,
#                     "option1": "Damaged Foil",
#                     "option2": null,
#                     "option3": null,
#                     "position": 10,
#                     "price": "2.75",
#                     "product_id": 8052474413219,
#                     "requires_shipping": true,
#                     "sku": "CMM-312-EN-FO-5",
#                     "taxable": true,
#                     "title": "Damaged Foil",
#                     "updated_at": "2023-07-24T18:30:50-03:00"
#                 }
#             ],
#             "vendor": "Magic: The Gathering"
#         },
#         {
#             "body_html": "<table class=\"singles-description-table\">\n<tbody>\n      <tr>\n          <td>Set:</td>\n          <td>Commander Masters</td>\n      </tr>\n      <tr>\n          <td>Type:</td>\n          <td>Creature \u2014 Elf Druid</td>\n      </tr>\n      <tr>\n          <td>Rarity:</td>\n          <td>Common</td>\n      </tr>\n      <tr>\n          <td>Cost:</td>\n          <td>{G}</td>\n      </tr>\n</tbody>\n</table>\n<div class=\"single-description-div\">\n        <div class=\"oracle-text\">\n            T: Add G.\n        </div>\n        <div class=\"flavor-text\">\n            \u201cThe Three Rings of the Elves were not made as weapons of war or conquest\u2014that is not their power. Those who made them did not desire strength or domination or hoarded wealth, but understanding, making, and healing, to preserve all things unstained.\u201d \n\u2014Elrond\n        </div>\n<table class=\"singles-reverse-description-table\">\n<tbody>\n</tbody>\n</table>\n<div class=\"single-description-div\">\n</div>\n<div class=\"catalogMetaData\" style=\"visibility: hidden;\" data-cardtype=\"mtg\" data-cardid=\"44199\" data-tcgid=\"507123\" data-lastupdated=\"2023-07-24T19:57:32.622Z\">\n</div>\n</div>",
#             "created_at": "2023-07-24T18:30:48-03:00",
#             "handle": "elvish-mystic-commander-masters",
#             "id": 8052474380451,
#             "images": [
#                 {
#                     "created_at": "2023-07-24T18:30:48-03:00",
#                     "height": 1040,
#                     "id": 37440406487203,
#                     "position": 1,
#                     "product_id": 8052474380451,
#                     "src": "https://cdn.shopify.com/s/files/1/0316/5585/4215/products/2d44fbc9-7e56-5eeb-b645-22f7d7480e45.png?v=1690234248",
#                     "updated_at": "2023-07-24T18:30:48-03:00",
#                     "variant_ids": [],
#                     "width": 745
#                 }
#             ],
#             "options": [
#                 {
#                     "name": "Title",
#                     "position": 1,
#                     "values": [
#                         "Near Mint",
#                         "Lightly Played",
#                         "Moderately Played",
#                         "Heavily Played",
#                         "Damaged",
#                         "Near Mint Foil",
#                         "Lightly Played Foil",
#                         "Moderately Played Foil",
#                         "Heavily Played Foil",
#                         "Damaged Foil"
#                     ]
#                 }
#             ],
#             "product_type": "MTG Single",
#             "published_at": "2023-07-24T18:30:47-03:00",
#             "tags": [
#                 "Commander Masters",
#                 "Common",
#                 "Creature",
#                 "Elf Druid",
#                 "Foil",
#                 "Green",
#                 "Normal"
#             ],
#             "title": "Elvish Mystic [Commander Masters]",
#             "updated_at": "2023-07-25T02:08:10-03:00",
#             "variants": [
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-24T18:30:48-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43480149360803,
#                     "option1": "Near Mint",
#                     "option2": null,
#                     "option3": null,
#                     "position": 1,
#                     "price": "0.50",
#                     "product_id": 8052474380451,
#                     "requires_shipping": true,
#                     "sku": "CMM-284-EN-NF-1",
#                     "taxable": true,
#                     "title": "Near Mint",
#                     "updated_at": "2023-07-24T18:30:48-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-24T18:30:48-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43480149426339,
#                     "option1": "Lightly Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 2,
#                     "price": "0.50",
#                     "product_id": 8052474380451,
#                     "requires_shipping": true,
#                     "sku": "CMM-284-EN-NF-2",
#                     "taxable": true,
#                     "title": "Lightly Played",
#                     "updated_at": "2023-07-24T18:30:48-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-24T18:30:48-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43480149524643,
#                     "option1": "Moderately Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 3,
#                     "price": "0.50",
#                     "product_id": 8052474380451,
#                     "requires_shipping": true,
#                     "sku": "CMM-284-EN-NF-3",
#                     "taxable": true,
#                     "title": "Moderately Played",
#                     "updated_at": "2023-07-24T18:30:48-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-24T18:30:48-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43480149590179,
#                     "option1": "Heavily Played",
#                     "option2": null,
#                     "option3": null,
#                     "position": 4,
#                     "price": "0.25",
#                     "product_id": 8052474380451,
#                     "requires_shipping": true,
#                     "sku": "CMM-284-EN-NF-4",
#                     "taxable": true,
#                     "title": "Heavily Played",
#                     "updated_at": "2023-07-24T18:30:48-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-24T18:30:48-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43480149655715,
#                     "option1": "Damaged",
#                     "option2": null,
#                     "option3": null,
#                     "position": 5,
#                     "price": "0.25",
#                     "product_id": 8052474380451,
#                     "requires_shipping": true,
#                     "sku": "CMM-284-EN-NF-5",
#                     "taxable": true,
#                     "title": "Damaged",
#                     "updated_at": "2023-07-24T18:30:48-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-24T18:30:49-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43480149721251,
#                     "option1": "Near Mint Foil",
#                     "option2": null,
#                     "option3": null,
#                     "position": 6,
#                     "price": "6.50",
#                     "product_id": 8052474380451,
#                     "requires_shipping": true,
#                     "sku": "CMM-284-EN-FO-1",
#                     "taxable": true,
#                     "title": "Near Mint Foil",
#                     "updated_at": "2023-07-24T18:30:49-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-24T18:30:49-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43480149754019,
#                     "option1": "Lightly Played Foil",
#                     "option2": null,
#                     "option3": null,
#                     "position": 7,
#                     "price": "5.75",
#                     "product_id": 8052474380451,
#                     "requires_shipping": true,
#                     "sku": "CMM-284-EN-FO-2",
#                     "taxable": true,
#                     "title": "Lightly Played Foil",
#                     "updated_at": "2023-07-24T18:30:49-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-24T18:30:49-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43480149786787,
#                     "option1": "Moderately Played Foil",
#                     "option2": null,
#                     "option3": null,
#                     "position": 8,
#                     "price": "4.50",
#                     "product_id": 8052474380451,
#                     "requires_shipping": true,
#                     "sku": "CMM-284-EN-FO-3",
#                     "taxable": true,
#                     "title": "Moderately Played Foil",
#                     "updated_at": "2023-07-24T18:30:49-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-24T18:30:49-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43480149819555,
#                     "option1": "Heavily Played Foil",
#                     "option2": null,
#                     "option3": null,
#                     "position": 9,
#                     "price": "3.25",
#                     "product_id": 8052474380451,
#                     "requires_shipping": true,
#                     "sku": "CMM-284-EN-FO-4",
#                     "taxable": true,
#                     "title": "Heavily Played Foil",
#                     "updated_at": "2023-07-24T18:30:49-03:00"
#                 },
#                 {
#                     "available": false,
#                     "compare_at_price": null,
#                     "created_at": "2023-07-24T18:30:49-03:00",
#                     "featured_image": null,
#                     "grams": 2,
#                     "id": 43480149852323,
#                     "option1": "Damaged Foil",
#                     "option2": null,
#                     "option3": null,
#                     "position": 10,
#                     "price": "2.50",
#                     "product_id": 8052474380451,
#                     "requires_shipping": true,
#                     "sku": "CMM-284-EN-FO-5",
#                     "taxable": true,
#                     "title": "Damaged Foil",
#                     "updated_at": "2023-07-25T02:08:10-03:00"
#                 }
#             ],
#             "vendor": "Magic: The Gathering"
#         }
#     ]
# }
# product_type
# MTG Single    247
# Board Game      3
# Name: count, dtype: int64

# %%
def get_products(url):
    """
    Get all products from a store.
    Returns:
        df: Pandas DataFrame of the products.json.
    """

    results = True
    page = 1
    df = pd.DataFrame()

    while results == True and page < 7:
        products_json = get_json(url, page + 7)
        products_dict = to_df(products_json)

        if len(products_dict) == 0:
            break
        else:
            df = pd.concat([df, products_dict], ignore_index=True)
            page += 1
            print(f"Page {page + 7} scraped...")

    df['url'] = f"{url}/products/" + df['handle']
    return df

# %%
result_df = get_products('https://exorgames.com')
print(result_df['product_type'].value_counts())
print(result_df.info())
# print images for each some product
for i in range(0, 10):
    print(result_df['images'][i][0]['src'])

# filter out product_type != MTG Single
result_df = result_df[result_df['product_type'] == 'MTG Single']
# convert to array of results
result_df = result_df.to_dict('records')
# Out:
# Page 9 scraped...
# Page 10 scraped...
# Page 11 scraped...
# Page 12 scraped...
# Page 13 scraped...
# Page 14 scraped...
# product_type
# MTG Single                628
# One Piece Single          259
# Flesh And Blood Single    236
# Yugioh Single             147
# Miniatures                127
# Event Ticket               49
# Supplies                   42
# Pokemon Single              8
# Board Games                 3
# Model                       1
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1500 non-null   int64
#  1   title         1500 non-null   object
#  2   handle        1500 non-null   object
#  3   body_html     1500 non-null   object
#  4   published_at  1500 non-null   object
#  5   created_at    1500 non-null   object
#  6   updated_at    1500 non-null   object
#  7   vendor        1500 non-null   object
#  8   product_type  1500 non-null   object
#  9   tags          1500 non-null   object
#  10  variants      1500 non-null   object
#  11  images        1500 non-null   object
#  12  options       1500 non-null   object
#  13  url           1500 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 164.2+ KB
# None
# https://cdn.shopify.com/s/files/1/0467/3083/8169/products/2f6c3a32-fd98-59f3-b3f1-62bf1662b616_df3c40ef-761e-459b-8e56-56868cac0833.png?v=1689622394
# https://cdn.shopify.com/s/files/1/0467/3083/8169/products/2c96acad-f3d8-5530-933f-d37174deee03_836b962d-18ce-4f92-bde4-b08f58a17010.png?v=1689622393
# https://cdn.shopify.com/s/files/1/0467/3083/8169/products/77aa2fbe-3e35-5611-ad48-f284127b6fd7_5b9cf804-089f-4aa0-bed9-edff64653647.png?v=1689622392
# https://cdn.shopify.com/s/files/1/0467/3083/8169/products/ae7b9a70-dfab-587d-a1d9-9f6bd0c53043_cf1a9f26-08da-4dd7-ae24-fd0e6d452181.png?v=1689622392
# https://cdn.shopify.com/s/files/1/0467/3083/8169/products/35ebf2e5-58c9-5d27-a965-4c6ca1f46800_0beff24a-9987-430b-96ce-bd77a28e6fc5.png?v=1689622391
# https://cdn.shopify.com/s/files/1/0467/3083/8169/products/957025e3-d5c0-58ff-ade4-cff4cbf3f62d_c0b0893c-15b1-4c0a-9485-94c16652dfa2.png?v=1689622390
# https://cdn.shopify.com/s/files/1/0467/3083/8169/products/35ebf2e5-58c9-5d27-a965-4c6ca1f46800_0b982aa9-81e7-493d-bf5e-0485c21945dd.png?v=1689622391
# https://cdn.shopify.com/s/files/1/0467/3083/8169/products/957025e3-d5c0-58ff-ade4-cff4cbf3f62d_42e00f3c-b709-4ba4-8381-05e0dc05e3ca.png?v=1689622389
# https://cdn.shopify.com/s/files/1/0467/3083/8169/products/704c5f63-b89f-5e03-817d-5c30640abed2_05291a16-4bf0-44f2-b2c0-54e17719eabd.png?v=1689622389
# https://cdn.shopify.com/s/files/1/0467/3083/8169/products/97df3aa8-ee33-548b-bcad-778ba644f616.png?v=1689622388

# %%
# only a few small adjustments needed to scraper for it to pull from myshopify.com/products.json directly.
scraper_results = []

for card in result_df:
    titleAndSet = card['title']
    if 'Art Card' in titleAndSet:
        continue
    # split the title and set
    title = titleAndSet.split("[")[0].strip()
    setName = titleAndSet.split("[")[1].split("]")[0].strip()

    # remove any excess tags inside () or [] in the title
    title = title.split("(")[0].strip()

    image = card['images'][0]['src']        # image adjusted
    handle = card['handle']
    link = card['url']

    for variant in card['variants']:
        if not variant['available']:
            continue

        condition = variant['title'].split(" ")[0].strip()
        if condition == "Lightly":
            condition = "LP"
        elif condition == "Near":
            condition = "NM"
        elif condition == "Moderately":
            condition = "MP"
        elif condition == "Heavily":
            condition = "HP"
        elif condition == "Damaged":
            condition = "DMG"
        
        foil = False
        if "Foil" in variant['title']:
            foil = True

        price = variant['price']

        scraper_results.append({
            'name': title,
            'link': link,
            'image': image,
            'set': setName,
            'condition': condition,
            'foil': foil,
            'price': price,
            'website': ""
        })

print(scraper_results)
# Out:
# [{'name': 'Oaken Brawler', 'link': 'https://exorgames.com/products/oaken-brawler-the-list', 'image': 'https://cdn.shopify.com/s/files/1/0467/3083/8169/products/3bcb0f29-5eee-5cd7-b7a1-0c23719b37e3.jpg?v=1689008128', 'set': 'The List', 'condition': 'NM', 'foil': False, 'price': '0.25', 'website': ''}, {'name': 'Rakdos Riteknife', 'link': 'https://exorgames.com/products/rakdos-riteknife-the-list', 'image': 'https://cdn.shopify.com/s/files/1/0467/3083/8169/products/1841c365-d76c-5cef-90ce-10dc403afa5e.jpg?v=1689008095', 'set': 'The List', 'condition': 'LP', 'foil': False, 'price': '0.90', 'website': ''}, {'name': 'Lobelia Sackville-Baggins', 'link': 'https://exorgames.com/products/lobelia-sackville-baggins-399-the-lord-of-the-rings-tales-of-middle-earth-prerelease-promos', 'image': 'https://cdn.shopify.com/s/files/1/0467/3083/8169/products/501093.jpg?v=1687376649', 'set': 'The Lord of the Rings: Tales of Middle-Earth Prerelease Promos', 'condition': 'NM', 'foil': True, 'price': '2.45', 'website': ''}, {'name': 'Acidic Slime', 'link': 'https://exorgames.com/products/acidic-slime-30th-anniversary-promos', 'image': 'https://cdn.shopify.com/s/files/1/0467/3083/8169/products/b99b007e-3a8d-5aad-a4ce-e68bcc0728e4_b4c49288-f17e-4cc4-bc66-932efe0cc102.jpg?v=1687376635', 'set': '30th Anniversary Promos', 'condition': 'NM', 'foil': True, 'price': '0.65', 'website': ''}, {'name': 'Minas Tirith', 'link': 'https://exorgames.com/products/minas-tirith-the-lord-of-the-rings-tales-of-middle-earth-prerelease-promos', 'image': 'https://cdn.shopify.com/s/files/1/0467/3083/8169/products/501305.jpg?v=1687061656', 'set': 'The Lord of the Rings: Tales of Middle-Earth Prerelease Promos', 'condition': 'NM', 'foil': True, 'price': '5.75', 'website': ''}, {'name': 'Sting, the Glinting Dagger', 'link': 'https://exorgames.com/products/sting-the-glinting-dagger-the-lord-of-the-rings-tales-of-middle-earth-prerelease-promos', 'image': 'https://cdn.shopify.com/s/files/1/0467/3083/8169/products/501279.jpg?v=1687061653', 'set': 'The Lord of the Rings: Tales of Middle-Earth Prerelease Promos', 'condition': 'NM', 'foil': True, 'price': '5.25', 'website': ''}, {'name': 'Merry, Esquire of Rohan', 'link': 'https://exorgames.com/products/merry-esquire-of-rohan-the-lord-of-the-rings-tales-of-middle-earth-prerelease-promos', 'image': 'https://cdn.shopify.com/s/files/1/0467/3083/8169/products/501306.jpg?v=1687061639', 'set': 'The Lord of the Rings: Tales of Middle-Earth Prerelease Promos', 'condition': 'NM', 'foil': True, 'price': '2.15', 'website': ''}, {'name': 'Legolas, Master Archer', 'link': 'https://exorgames.com/products/legolas-master-archer-the-lord-of-the-rings-tales-of-middle-earth-prerelease-promos', 'image': 'https://cdn.shopify.com/s/files/1/0467/3083/8169/products/501309.jpg?v=1687061628', 'set': 'The Lord of the Rings: Tales of Middle-Earth Prerelease Promos', 'condition': 'NM', 'foil': True, 'price': '3.10', 'website': ''}, {'name': 'Hew the Entwood', 'link': 'https://exorgames.com/products/hew-the-entwood-the-lord-of-the-rings-tales-of-middle-earth-prerelease-promos', 'image': 'https://cdn.shopify.com/s/files/1/0467/3083/8169/products/501315.jpg?v=1687061623', 'set': 'The Lord of the Rings: Tales of Middle-Earth Prerelease Promos', 'condition': 'NM', 'foil': True, 'price': '3.30', 'website': ''}, {'name': 'Flowering of the White Tree', 'link': 'https://exorgames.com/products/flowering-of-the-white-tree-the-lord-of-the-rings-tales-of-middle-earth-prerelease-promos', 'image': 'https://cdn.shopify.com/s/files/1/0467/3083/8169/products/501329.jpg?v=1687061601', 'set': 'The Lord of the Rings: Tales of Middle-Earth Prerelease Promos', 'condition': 'NM', 'foil': True, 'price': '11.10', 'website': ''}, {'name': 'Pippin, Guard of the Citadel', 'link': 'https://exorgames.com/products/pippin-guard-of-the-citadel-the-lord-of-the-rings-tales-of-middle-earth-prerelease-promos', 'image': 'https://cdn.shopify.com/s/files/1/0467/3083/8169/products/501298.jpg?v=1687061590',  ...
